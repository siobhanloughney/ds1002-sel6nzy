# %% [markdown]
# <a href="https://colab.research.google.com/github/siobhanloughney/ds1002-sel6nzy/blob/main/InClass_9/22/23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
# matplotlib is math plot library. importing small subset of it called pyplot
# %matplotlib inline
# when you plot, give it inline here in the notebook. otherwise, it might create a gif file and download it to your computer. could be helpful if you need the plots to export somewhere

# %%
# import the mockaroo file
# under the hood we're creating a pandas object - a dataframe - it's an OBJECT not just a variable name we're creating
mock_data = pd.read_csv("MOCK_DATA.csv")
#drag file into colab

# %%
# get basic info about the dataframe
mock_data.info()
# an "object" in pandas is a string to regular python
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# note stop=1000; we asked mockaroo for 1000 plus including the header row
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# get the head rows - whatever number i want
mock_data.head(30)
# mock_data.head() will default to 5 rows, but entering anumber in the () can change that
# Out:
#     id  first_name    last_name                        email       gender  age
# 0    1      Hollie      Nesbeth   hnesbeth0@sciencedaily.com       Female    8
# 1    2      Frasco     Petrozzi           fpetrozzi1@mapy.cz      Agender   23
# 2    3       Polly        Axell            paxell2@imgur.com  Genderfluid    5
# 3    4   Charlotte   Folcarelli       cfolcarelli3@goo.ne.jp       Female   54
# 4    5      Seward       Fruish           sfruish4@wikia.com         Male   20
# 5    6       Brant  Killingbeck   bkillingbeck5@yolasite.com      Agender    3
# 6    7      Dniren    Rawcliffe             drawcliffe6@g.co       Female   45
# 7    8        Luke   De Caville    ldecaville7@shinystat.com         Male   23
# 8    9      Sibley       Drejer        sdrejer8@symantec.com       Female   11
# 9   10     Barnabe      Howling             bhowling9@vk.com  Genderfluid   28
# 10  11         Isa     Colenutt     icolenutta@parallels.com   Non-binary   55
# ...

# %%
# get header and last 5 rows
mock_data.tail(15)
# Out:
#        id first_name     last_name                         email       gender  \
# 985   986     Jarred      Wanstall        jwanstallrd@taobao.com         Male
# 986   987  Maryellen     Stockport         mstockportre@ox.ac.uk       Female
# 987   988       Rosy         Joist            rjoistrf@tmall.com       Female
# 988   989    Minerva     Colleford       mcollefordrg@seesaa.net       Female
# 989   990    Saundra    Benardette        sbenardetterh@youtu.be       Female
# 990   991     Ronald        Stowte             rstowteri@ovh.net         Male
# 991   992     Giffie          Elph               gelphrj@fc2.com         Male
# 992   993   Eustacia      Edwicker   eedwickerrk@hugedomains.com       Female
# 993   994        Ara        Decker           adeckerrl@google.es         Male
# 994   995      Anson      MacAvddy              amacavddyrm@t.co         Male
# 995   996        May   Maffioletti        mmaffiolettirn@irs.gov       Female
# ...

# %%
# location - give it the index
# don't forget the zero index
mock_data.loc[900]
# Out:
# id                            901
# first_name                Ulysses
# last_name                Casarili
# email         ucasarilip0@dot.gov
# gender                       Male
# age                            33
# Name: 900, dtype: object

# %%
# mock_data.method(parameter)
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    46.271000
# std     288.819436    25.898886
# min       1.000000     1.000000
# 25%     250.750000    24.000000
# 50%     500.500000    48.000000
# 75%     750.250000    68.000000
# max    1000.000000    90.000000

# %%
# get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
# what data types are in the df?
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
# whatever you do on the right is going to rewrite the left
# note that we're creating a dictionary on the right
# give columns title as key, new name as value
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id      fname       lname                       email       gender  age
# 0   1     Hollie     Nesbeth  hnesbeth0@sciencedaily.com       Female    8
# 1   2     Frasco    Petrozzi          fpetrozzi1@mapy.cz      Agender   23
# 2   3      Polly       Axell           paxell2@imgur.com  Genderfluid    5
# 3   4  Charlotte  Folcarelli      cfolcarelli3@goo.ne.jp       Female   54
# 4   5     Seward      Fruish          sfruish4@wikia.com         Male   20

# %%
mock_data['fname']
# Out:
# 0         Hollie
# 1         Frasco
# 2          Polly
# 3      Charlotte
# 4         Seward
#          ...
# 995          May
# 996     Birgitta
# 997        Sylas
# 998       Sigrid
# 999     Michelle
# Name: fname, Length: 1000, dtype: object

# %%
# another way to do the same thing as the last block
mock_data.fname
# Out:
# 0         Hollie
# 1         Frasco
# 2          Polly
# 3      Charlotte
# 4         Seward
#          ...
# 995          May
# 996     Birgitta
# 997        Sylas
# 998       Sigrid
# 999     Michelle
# Name: fname, Length: 1000, dtype: object

# %%
mock_data[['fname','lname']]
# Out:
#          fname         lname
# 0       Hollie       Nesbeth
# 1       Frasco      Petrozzi
# 2        Polly         Axell
# 3    Charlotte    Folcarelli
# 4       Seward        Fruish
# ..         ...           ...
# 995        May   Maffioletti
# 996   Birgitta      Jahnisch
# 997      Sylas  MacGillacolm
# 998     Sigrid      Mortimer
# 999   Michelle      Ibbotson
#
# [1000 rows x 2 columns]

# %%
# pandas . value counts method (data frame)
pd.value_counts(mock_data['gender']).plot.bar()
# PYTHON IS CASE SENSITIVE!
# Out:
# <Axes: >

# %%
# group by gender,
#save to github and add mock data to github repo
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        49.950000
# Bigender       50.583333
# Female         47.481641
# Genderfluid    33.733333
# Genderqueer    41.409091
# Male           45.172414
# Non-binary     50.928571
# Polygender     47.421053
# Name: age, dtype: float64
